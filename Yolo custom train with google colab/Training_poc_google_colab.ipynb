# %% [markdown]
# **Check graphic card**

# %%
# !nvidia-smi
# Out:
# Wed Jan 10 10:39:42 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# **Install ultralytics dependence**

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.2/699.2 kB 8.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Test if it's working**
# Should be : 5 persons, 1 bicycle, 1 bus

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source="https://ultralytics.com/images/bus.jpg"
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 346MB/s]
# Ultralytics YOLOv8.1.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients, 165.2 GFLOPs
#
# ...
# 100% 476k/476k [00:00<00:00, 30.9MB/s]
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/bus.jpg: 640x480 5 persons, 1 bicycle, 1 bus, 228.2ms
# Speed: 13.5ms preprocess, 228.2ms inference, 1068.6ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **Begin the training**

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=../content/drive/MyDrive/YolovPOC/data.yaml epochs=500 imgsz=640
# Out:
# Ultralytics YOLOv8.1.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
